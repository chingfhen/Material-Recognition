# %%
import loader
import matplotlib.pyplot as plt

# %% [markdown]
# ## loader.load_FMD
# - returns X_train, y_train, X_test, y_test in numpy arrays

# %%
data_dir = r"C:\Users\tanch\Documents\NTU\NTU Year 3\Sem 1\CZ4042 Deep Learning and Neural Networks\Assignment 2\code\data\FMD (1)\image"
X_train, y_train, X_test, y_test = loader.load_FMD(data_dir,(200,200))

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((797, 200, 200, 3), (797,), (200, 200, 200, 3), (200,))

# %%
plt.imshow(X_test[0])

# %%
y_test
# Out:
# array([1, 1, 5, 6, 6, 4, 6, 1, 7, 2, 8, 3, 8, 2, 4, 4, 6, 0, 3, 2, 2, 2,
#        0, 5, 8, 6, 2, 2, 5, 9, 4, 1, 3, 9, 9, 2, 8, 9, 1, 0, 0, 3, 7, 0,
#        0, 0, 7, 0, 9, 0, 0, 7, 4, 5, 2, 1, 7, 5, 1, 7, 5, 0, 3, 1, 7, 0,
#        8, 5, 3, 5, 3, 2, 3, 5, 6, 3, 8, 8, 2, 6, 2, 6, 1, 0, 9, 9, 1, 5,
#        3, 5, 8, 3, 7, 7, 2, 6, 1, 8, 1, 8, 1, 9, 0, 7, 3, 2, 0, 6, 5, 6,
#        4, 8, 0, 0, 4, 7, 1, 8, 2, 0, 3, 2, 8, 9, 4, 0, 6, 3, 3, 2, 7, 4,
#        5, 9, 0, 9, 1, 8, 0, 1, 8, 4, 5, 6, 1, 2, 7, 5, 5, 6, 6, 2, 2, 4,
#        9, 1, 6, 7, 9, 1, 0, 8, 4, 4, 8, 7, 7, 1, 9, 7, 0, 8, 5, 6, 8, 9,
#        1, 0, 5, 4, 7, 3, 3, 6, 4, 0, 6, 8, 7, 2, 7, 0, 3, 7, 7, 8, 1, 6,
#        5, 6])

# %% [markdown]
# ## loader.read_image
# - returns image or numpy arrays

# %%
path = r"C:\Users\tanch\Documents\NTU\NTU Year 3\Sem 1\CZ4042 Deep Learning and Neural Networks\Assignment 2\code\data\FMD (1)\image\fabric\fabric_moderate_001_new.jpg"
loader.read_image(path, new_size = None, to_array = False)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x25688BFB760>
